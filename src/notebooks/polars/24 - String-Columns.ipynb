# %% [markdown]
# # Filtering rows: String Columns
# By the end of this lecture you will be able to:
#
# - `Select` columns
# - use `=` `!` Condition in `filter`
# - use `in` condition in `filter`
# - use `Like` condition in `filter`
#
# # 筛选行：字符串列
#
# 本讲结束时，您将能够：
#
# - `Select` 列
#
# - 在 `filter` 中使用 `=` 和 `!` 条件
#
# - 在 `filter` 中使用 `in` 条件
#
# - 在 `filter` 中使用 `Like` 条件

# %%
import polars as pl

# %%
df = pl.read_csv("../../Files/Sample_Superstore.csv")

# %%
df.head()
# Out:
# shape: (5, 21)
# ┌────────┬────────────────┬────────────┬────────────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ Row_ID ┆ Order_ID       ┆ Order_Date ┆ Ship_Date  ┆ … ┆ Sales    ┆ Quantity ┆ Discount ┆ Profit   │
# │ ---    ┆ ---            ┆ ---        ┆ ---        ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ i64    ┆ str            ┆ str        ┆ str        ┆   ┆ f64      ┆ i64      ┆ f64      ┆ f64      │
# ╞════════╪════════════════╪════════════╪════════════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ 1      ┆ null           ┆ null       ┆ 11-11-2016 ┆ … ┆ 261.96   ┆ 2        ┆ 0.0      ┆ 41.9136  │
# │ 2      ┆ CA-2016-152156 ┆ 08-11-2016 ┆ 11-11-2016 ┆ … ┆ 731.94   ┆ 3        ┆ 0.0      ┆ 219.582  │
# │ 3      ┆ CA-2016-138688 ┆ 12-06-2016 ┆ null       ┆ … ┆ 14.62    ┆ 2        ┆ 0.0      ┆ 6.8714   │
# │ 4      ┆ null           ┆ 11-10-2015 ┆ null       ┆ … ┆ 957.5775 ┆ 5        ┆ 0.45     ┆ -383.031 │
# │ 5      ┆ US-2015-108966 ┆ 11-10-2015 ┆ 18-10-2015 ┆ … ┆ 22.368   ┆ 2        ┆ 0.2      ┆ 2.5164   │
# └────────┴────────────────┴────────────┴────────────┴───┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# ## Selecting columns
#
# We can select columns with an expression in the `select` method
#
# ## 选择列
#
# 我们可以使用 `select` 方法中的表达式来选择列。

# %%
df.select(pl.col("Customer_Name", "Segment")).head(3)
# Out:
# shape: (3, 2)
# ┌─────────────────┬───────────┐
# │ Customer_Name   ┆ Segment   │
# │ ---             ┆ ---       │
# │ str             ┆ str       │
# ╞═════════════════╪═══════════╡
# │ Claire Gute     ┆ Consumer  │
# │ Claire Gute     ┆ Consumer  │
# │ Darrin Van Huff ┆ Corporate │
# └─────────────────┴───────────┘

# %% [markdown]
# ## Apply `EQUAL` Condition
#
# In this example we choose all rows `City` is `Henderson`
#
#
# ## 应用“等于”条件
#
# 在本例中，我们选择所有“城市”为“亨德森”的行。

# %%
(df.filter(pl.col("City") == "Henderson").head())
# Out:
# shape: (5, 21)
# ┌────────┬────────────────┬────────────┬────────────┬───┬────────┬──────────┬──────────┬─────────┐
# │ Row_ID ┆ Order_ID       ┆ Order_Date ┆ Ship_Date  ┆ … ┆ Sales  ┆ Quantity ┆ Discount ┆ Profit  │
# │ ---    ┆ ---            ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---      ┆ ---      ┆ ---     │
# │ i64    ┆ str            ┆ str        ┆ str        ┆   ┆ f64    ┆ i64      ┆ f64      ┆ f64     │
# ╞════════╪════════════════╪════════════╪════════════╪═══╪════════╪══════════╪══════════╪═════════╡
# │ 1      ┆ null           ┆ null       ┆ 11-11-2016 ┆ … ┆ 261.96 ┆ 2        ┆ 0.0      ┆ 41.9136 │
# │ 2      ┆ CA-2016-152156 ┆ 08-11-2016 ┆ 11-11-2016 ┆ … ┆ 731.94 ┆ 3        ┆ 0.0      ┆ 219.582 │
# │ 539    ┆ CA-2015-134894 ┆ 07-12-2015 ┆ 11-12-2015 ┆ … ┆ 152.94 ┆ 3        ┆ 0.0      ┆ 41.2938 │
# │ 540    ┆ CA-2015-134894 ┆ 07-12-2015 ┆ 11-12-2015 ┆ … ┆ 283.92 ┆ 4        ┆ 0.0      ┆ 70.98   │
# │ 997    ┆ CA-2015-162537 ┆ 28-10-2015 ┆ 03-11-2015 ┆ … ┆ 10.67  ┆ 1        ┆ 0.0      ┆ 4.9082  │
# └────────┴────────────────┴────────────┴────────────┴───┴────────┴──────────┴──────────┴─────────┘

# %% [markdown]
# As well as the mathemtical operators such as `=!`,`>`,`<` there are corresponding text operators that some people find more readable
#
# 除了诸如 `=!`、`>`、`<` 之类的数学运算符之外，还有一些对应的文本运算符，有些人觉得这些运算符更易于阅读。

# %% [markdown]
# ## Apply `IN` condition
#
# you can use the `is_in` method to filter rows based on whether the values in a column match any value from a list or set.
#
# ## 应用 `IN` 条件
#
# 您可以使用 `is_in` 方法根据列中的值是否与列表或集合中的任何值匹配来筛选行。

# %%
(df.filter(pl.col("City").is_in(["Los Angeles", "Henderson"])).head())
# Out:
# shape: (5, 21)
# ┌────────┬────────────────┬────────────┬────────────┬───┬────────┬──────────┬──────────┬─────────┐
# │ Row_ID ┆ Order_ID       ┆ Order_Date ┆ Ship_Date  ┆ … ┆ Sales  ┆ Quantity ┆ Discount ┆ Profit  │
# │ ---    ┆ ---            ┆ ---        ┆ ---        ┆   ┆ ---    ┆ ---      ┆ ---      ┆ ---     │
# │ i64    ┆ str            ┆ str        ┆ str        ┆   ┆ f64    ┆ i64      ┆ f64      ┆ f64     │
# ╞════════╪════════════════╪════════════╪════════════╪═══╪════════╪══════════╪══════════╪═════════╡
# │ 1      ┆ null           ┆ null       ┆ 11-11-2016 ┆ … ┆ 261.96 ┆ 2        ┆ 0.0      ┆ 41.9136 │
# │ 2      ┆ CA-2016-152156 ┆ 08-11-2016 ┆ 11-11-2016 ┆ … ┆ 731.94 ┆ 3        ┆ 0.0      ┆ 219.582 │
# │ 3      ┆ CA-2016-138688 ┆ 12-06-2016 ┆ null       ┆ … ┆ 14.62  ┆ 2        ┆ 0.0      ┆ 6.8714  │
# │ 6      ┆ CA-2014-115812 ┆ 09-06-2014 ┆ 14-06-2014 ┆ … ┆ 48.86  ┆ 7        ┆ 0.0      ┆ 14.1694 │
# │ 7      ┆ CA-2014-115812 ┆ 09-06-2014 ┆ 14-06-2014 ┆ … ┆ 7.28   ┆ 4        ┆ 0.0      ┆ 1.9656  │
# └────────┴────────────────┴────────────┴────────────┴───┴────────┴──────────┴──────────┴─────────┘

# %% [markdown]
# ## Apply `Contain` condition
#
# The filter method applies this condition, returning rows where the `Customer_Name` includes "Gene Hale".
#
# ## 应用“包含”条件
#
# 筛选方法应用此条件，返回 `Customer_Name` 包含“Gene Hale”的行。

# %%
(df.filter(pl.col("Customer_Name").str.contains("Gene Hale")).head())
# Out:
# shape: (3, 21)
# ┌────────┬────────────────┬────────────┬────────────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ Row_ID ┆ Order_ID       ┆ Order_Date ┆ Ship_Date  ┆ … ┆ Sales    ┆ Quantity ┆ Discount ┆ Profit   │
# │ ---    ┆ ---            ┆ ---        ┆ ---        ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ i64    ┆ str            ┆ str        ┆ str        ┆   ┆ f64      ┆ i64      ┆ f64      ┆ f64      │
# ╞════════╪════════════════╪════════════╪════════════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ 36     ┆ CA-2016-117590 ┆ 08-12-2016 ┆ 10-12-2016 ┆ … ┆ 1097.544 ┆ 7        ┆ 0.2      ┆ 123.4737 │
# │ 37     ┆ CA-2016-117590 ┆ 08-12-2016 ┆ 10-12-2016 ┆ … ┆ 190.92   ┆ 5        ┆ 0.6      ┆ -147.963 │
# │ 8134   ┆ CA-2015-131352 ┆ 08-10-2015 ┆ 13-10-2015 ┆ … ┆ 72.78    ┆ 3        ┆ 0.6      ┆ -70.9605 │
# └────────┴────────────────┴────────────┴────────────┴───┴──────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# ### Apply `AND` conditions
#
# We can apply filter `AND` conditions where all conditions must be met in a number of ways.
#
# In this example we look for rows where the `Quantity` is 5 `AND` the `Profit` is over 500
#
# ### 应用“与”条件
#
# 我们可以应用“与”筛选条件，其中所有条件必须以多种方式同时满足。
#
# 在本例中，我们查找“数量”为 5 且“利润”大于 500 的行。

# %%
(
    df.filter(
        (pl.col("Customer_Name") == "Gene Hale") & (pl.col("Segment") == "Corporate")
    ).head(2)
)
# Out:
# shape: (2, 21)
# ┌────────┬────────────────┬────────────┬────────────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ Row_ID ┆ Order_ID       ┆ Order_Date ┆ Ship_Date  ┆ … ┆ Sales    ┆ Quantity ┆ Discount ┆ Profit   │
# │ ---    ┆ ---            ┆ ---        ┆ ---        ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ i64    ┆ str            ┆ str        ┆ str        ┆   ┆ f64      ┆ i64      ┆ f64      ┆ f64      │
# ╞════════╪════════════════╪════════════╪════════════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ 36     ┆ CA-2016-117590 ┆ 08-12-2016 ┆ 10-12-2016 ┆ … ┆ 1097.544 ┆ 7        ┆ 0.2      ┆ 123.4737 │
# │ 37     ┆ CA-2016-117590 ┆ 08-12-2016 ┆ 10-12-2016 ┆ … ┆ 190.92   ┆ 5        ┆ 0.6      ┆ -147.963 │
# └────────┴────────────────┴────────────┴────────────┴───┴──────────┴──────────┴──────────┴──────────┘
